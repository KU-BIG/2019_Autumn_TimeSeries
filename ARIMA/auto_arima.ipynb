# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/data
# Out:
# /content/drive/My Drive/data

# %%
import pandas as pd

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
w_train = pd.read_csv("weather_train.csv")
w_test = pd.read_csv("weather_test.csv")
meta_building = pd.read_csv("building_metadata.csv")

# %%
mer_data = pd.merge(train, meta_building, on = 'building_id')

# %%
mer_data.head()
# Out:
#    building_id  meter  ... year_built  floor_count
# 0            0      0  ...     2008.0          NaN
# 1            0      0  ...     2008.0          NaN
# 2            0      0  ...     2008.0          NaN
# 3            0      0  ...     2008.0          NaN
# 4            0      0  ...     2008.0          NaN
#
# [5 rows x 9 columns]

# %%
set(mer_data['primary_use'])
# Out:
# {'Education',
#  'Entertainment/public assembly',
#  'Food sales and service',
#  'Healthcare',
#  'Lodging/residential',
#  'Manufacturing/industrial',
#  'Office',
#  'Other',
#  'Parking',
#  'Public services',
#  'Religious worship',
#  'Retail',
#  'Services',
#  'Technology/science',
#  'Utility',
#  'Warehouse/storage'}

# %%
mer2_data = mer_data[(mer_data['site_id']==2)&(mer_data['primary_use']=='Office')]

# %%
mer2_data.head()
# Out:
#          building_id  meter  ... year_built  floor_count
# 1620351          157      0  ...        NaN          NaN
# 1620352          157      0  ...        NaN          NaN
# 1620353          157      0  ...        NaN          NaN
# 1620354          157      0  ...        NaN          NaN
# 1620355          157      0  ...        NaN          NaN
#
# [5 rows x 9 columns]

# %%
site2_office = mer2_data.groupby(['timestamp'])['meter_reading'].sum()

# %%
site2_office
# Out:
# timestamp
# 2016-01-01 00:00:00    2733.1470
# 2016-01-01 01:00:00    2727.7944
# 2016-01-01 02:00:00    2777.4856
# 2016-01-01 03:00:00    2874.1859
# 2016-01-01 04:00:00    2945.0675
#                          ...
# 2016-12-31 19:00:00    2849.6376
# 2016-12-31 20:00:00    2845.4954
# 2016-12-31 21:00:00    2838.7294
# 2016-12-31 22:00:00    2652.2397
# 2016-12-31 23:00:00    2605.6898
# Name: meter_reading, Length: 8784, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
# !pip install pyramid.arima
# Out:
# Collecting pyramid.arima
#   Downloading https://files.pythonhosted.org/packages/5c/84/57422f2a6ade3161c586545e38b518ba1b7ab30ee4a4acc29110c0aba2bc/pyramid_arima-0.9.0-cp36-cp36m-manylinux1_x86_64.whl (597kB)
#      |████████████████████████████████| 604kB 5.1MB/s
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.6/dist-packages (from pyramid.arima) (0.25.3)
# Requirement already satisfied: Cython>=0.23 in /usr/local/lib/python3.6/dist-packages (from pyramid.arima) (0.29.14)
# Requirement already satisfied: scikit-learn>=0.17 in /usr/local/lib/python3.6/dist-packages (from pyramid.arima) (0.21.3)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.6/dist-packages (from pyramid.arima) (0.10.1)
# Requirement already satisfied: numpy>=1.10 in /usr/local/lib/python3.6/dist-packages (from pyramid.arima) (1.17.4)
# Requirement already satisfied: scipy>=0.9 in /usr/local/lib/python3.6/dist-packages (from pyramid.arima) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19->pyramid.arima) (2.6.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19->pyramid.arima) (2018.9)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.17->pyramid.arima) (0.14.0)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from statsmodels>=0.9.0->pyramid.arima) (0.5.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas>=0.19->pyramid.arima) (1.12.0)
# Installing collected packages: pyramid.arima
# Successfully installed pyramid.arima

# %%
from pyramid.arima import auto_arima

# %%
import statsmodels.tsa

# %%
np.argmin(statsmodels.tsa.stattools.pacf(total3['meter_reading'],nlags=400))
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/regression/linear_model.py:1358: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)
# 345

# %%
statsmodels.tsa.stattools.pacf(total3['meter_reading'])
# Out:
# array([ 1.        ,  0.97396275, -0.6191259 , -0.14623903, -0.16308026,
#        -0.124705  ,  0.00472402,  0.13442026,  0.11153502,  0.09232125,
#         0.14821811,  0.2049728 ,  0.15264499,  0.09657113,  0.19026704,
#         0.17802076,  0.08201226,  0.14895655,  0.17760891,  0.13401211,
#         0.04059858,  0.05518109,  0.08846634,  0.05053221, -0.16051853,
#        -0.35156359, -0.15669166,  0.00865804,  0.00735726,  0.02980266,
#         0.02384198,  0.05214041,  0.03577906,  0.0248108 ,  0.00269162,
#         0.00240805,  0.01863784, -0.01505159,  0.01472743, -0.00287138,
#        -0.0214162 ])

# %%
346/24
# Out:
# 14.416666666666666

# %%
plot_acf(total3['meter_reading'].diff(1).dropna(),lags=500)


plot_pacf(total3['meter_reading'].diff(1).dropna(),lags=500)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/regression/linear_model.py:1358: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %%
fig, axes = plt.subplots(2,1)
plot_acf(site2_office, lags=200, ax=axes[0])
plot_pacf(site2_office, lags=100, ax=axes[1])
plt.show()

# %%
plot_pacf(site2_office, lags=100)
plt.show()

# %%
fig, axes = plt.subplots(2,1)
plot_acf(site2_office, lags=[24,48,72,96,120,144,168,192,216,240,264,288], ax=axes[0])
plot_pacf(site2_office, lags=[24,48,72,96,120,144,168,192,216,240,264,288], ax=axes[1])
plt.show()

# %%
import numpy as np

# %%
fig = plt.figure(figsize=(200,7))
plt.plot(total2['meter_reading'])

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Perform additive decomposition
decomp = seasonal_decompose(total2.iloc[:,1][1:1000],model = 'additive', 
                            freq=24)

# Plot decomposition

decomp.plot()
plt.show()

# %%
total3 = total2.copy()

# %%
total3
# Out:
#                 timestamp  meter_reading  ...  sea_level_pressure  wind_speed
# 0     2016-01-01 00:00:00       0.221033  ...            0.553633    0.233766
# 1     2016-01-01 01:00:00       0.220558  ...            0.564014    0.266234
# 2     2016-01-01 02:00:00       0.224972  ...            0.577855    0.201299
# 3     2016-01-01 03:00:00       0.233563  ...            0.598616    0.201299
# 4     2016-01-01 04:00:00       0.239860  ...            0.612457    0.201299
# ...                   ...            ...  ...                 ...         ...
# 8779  2016-12-31 19:00:00       0.231382  ...            0.453287    0.233766
# 8780  2016-12-31 20:00:00       0.231014  ...            0.429066    0.233766
# 8781  2016-12-31 21:00:00       0.230413  ...            0.411765    0.298701
# 8782  2016-12-31 22:00:00       0.213846  ...            0.404844    0.233766
# 8783  2016-12-31 23:00:00       0.209710  ...            0.404844    0.168831
#
# [8784 rows x 7 columns]

# %%
tmp = total3['meter_reading'] - total3['meter_reading'].rolling(24).mean()
# Drop NaN values
tmp = tmp.dropna()
fig, axes = plt.subplots(2,1)
plot_acf(tmp, lags=200, ax=axes[0])
plot_pacf(tmp, lags=100, ax=axes[1])
plt.show()

# %%
auto_arima()
# Out:
# (0, 7)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model = SARIMAX(df, order=(p,d,q), seasonal_order=(P,D,Q,24))

# %%
fig, axes = plt.subplots(2,1)
plot_acf(total3['meter_reading'], lags=200, ax=axes[0])
plot_pacf(total3['meter_reading'], lags=100, ax=axes[1])
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/stattools.py:386: RuntimeWarning: Mean of empty slice.
#   xo = x - x.mean()
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-bc4727780a66> in <module>()
#       1 fig, axes = plt.subplots(2,1)
# ----> 2 plot_acf(total3['meter_reading'], lags=200, ax=axes[0])
#       3 plot_pacf(total3['meter_reading'], lags=100, ax=axes[1])
#       4 plt.show()
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/graphics/tsaplots.py in plot_acf(x, ax, lags, alpha, use_vlines, unbiased, fft, title, zero, vlines_kwargs, **kwargs)
#     151     else:
#     152         acf_x, confint = acf(x, nlags=nlags, alpha=alpha, fft=fft,
# --> 153                              unbiased=unbiased)
#     154
#     155     _plot_corr(ax, title, acf_x, confint, lags, irregular, use_vlines,
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/stattools.py in acf(x, unbiased, nlags, qstat, fft, alpha, missing)
#     543
#     544     nobs = len(x)  # should this shrink for missing='drop' and NaNs in x?
# --> 545     avf = acovf(x, unbiased=unbiased, demean=True, fft=fft, missing=missing)
#     546     acf = avf[:nlags + 1] / avf[0]
#     547     if not (qstat or alpha):
#
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/stattools.py in acovf(x, unbiased, demean, fft, missing, nlag)
#     426         d = notmask_int.sum() * np.ones(2 * n - 1)
#     427     else:  # biased and no NaNs or missing=='none'
# --> 428         d = n * np.ones(2 * n - 1)
#     429
#     430     if fft:
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/numeric.py in ones(shape, dtype, order)
#     212
#     213     """
# --> 214     a = empty(shape, dtype, order)
#     215     multiarray.copyto(a, 1, casting='unsafe')
#     216     return a
#
# ValueError: negative dimensions are not allowed

# %%
pd.DataFrame(np.array(total2.iloc[:,1:]) +1)[0]
# Out:
# 0       1.221033
# 1       1.220558
# 2       1.224972
# 3       1.233563
# 4       1.239860
#           ...
# 8779    1.231382
# 8780    1.231014
# 8781    1.230413
# 8782    1.213846
# 8783    1.209710
# Name: 0, Length: 8784, dtype: float64

# %%
site2_weather = w_train[w_train['site_id'] == 2]

# %%
site2_weather.head()
# Out:
#        site_id            timestamp  ...  wind_direction  wind_speed
# 17547        2  2016-01-01 00:00:00  ...           270.0         3.6
# 17548        2  2016-01-01 01:00:00  ...           270.0         4.1
# 17549        2  2016-01-01 02:00:00  ...           270.0         3.1
# 17550        2  2016-01-01 03:00:00  ...           280.0         3.1
# 17551        2  2016-01-01 04:00:00  ...           270.0         3.1
#
# [5 rows x 9 columns]

# %%
site2_weather.isnull().sum()
# Out:
# site_id                  0
# timestamp                0
# air_temperature          1
# cloud_coverage        2354
# dew_temperature          1
# precip_depth_1_hr       66
# sea_level_pressure      44
# wind_direction         591
# wind_speed               5
# dtype: int64

# %%
exo2 = site2_weather[['timestamp','air_temperature','dew_temperature','precip_depth_1_hr','sea_level_pressure','wind_speed']]

# %%
exo2.shape
# Out:
# (8783, 6)

# %%
exo2 = exo2.fillna(method='bfill')

# %%
exo2.head()
# Out:
#                  timestamp  air_temperature  ...  sea_level_pressure  wind_speed
# 17547  2016-01-01 00:00:00             15.6  ...              1015.3         3.6
# 17548  2016-01-01 01:00:00             13.9  ...              1015.6         4.1
# 17549  2016-01-01 02:00:00             13.3  ...              1016.0         3.1
# 17550  2016-01-01 03:00:00             12.2  ...              1016.6         3.1
# 17551  2016-01-01 04:00:00             11.7  ...              1017.0         3.1
#
# [5 rows x 6 columns]

# %%
exo2.shape
# Out:
# (8783, 5)

# %%
site2_office.shape
# Out:
# (8784,)

# %%
exo2.tail()
# Out:
#                  timestamp  air_temperature  ...  sea_level_pressure  wind_speed
# 26325  2016-12-31 19:00:00             15.0  ...              1012.4         3.6
# 26326  2016-12-31 20:00:00             16.1  ...              1011.7         3.6
# 26327  2016-12-31 21:00:00             16.7  ...              1011.2         4.6
# 26328  2016-12-31 22:00:00             16.7  ...              1011.0         3.6
# 26329  2016-12-31 23:00:00             16.7  ...              1011.0         2.6
#
# [5 rows x 6 columns]

# %%
site2_office.tail()
# Out:
# timestamp
# 2016-12-31 19:00:00    2849.6376
# 2016-12-31 20:00:00    2845.4954
# 2016-12-31 21:00:00    2838.7294
# 2016-12-31 22:00:00    2652.2397
# 2016-12-31 23:00:00    2605.6898
# Name: meter_reading, dtype: float64

# %%
site2_office.head()
# Out:
# timestamp
# 2016-01-01 00:00:00    2733.1470
# 2016-01-01 01:00:00    2727.7944
# 2016-01-01 02:00:00    2777.4856
# 2016-01-01 03:00:00    2874.1859
# 2016-01-01 04:00:00    2945.0675
# Name: meter_reading, dtype: float64

# %%
pd.merge(site2_office,exo2, how='outer', on='timestamp').isnull().sum()
# Out:
# timestamp             0
# meter_reading         0
# air_temperature       1
# dew_temperature       1
# precip_depth_1_hr     1
# sea_level_pressure    1
# wind_speed            1
# dtype: int64

# %%
total = pd.merge(site2_office,exo2, how='outer', on='timestamp').fillna(method='bfill')

# %%
total2 = total.copy()

# %%
from sklearn import preprocessing

# %%
min_max_scaler = preprocessing.MinMaxScaler()
for i in [1,2,3,4,5,6] :
  
  float_array = total.iloc[:,i].values.astype(float)
  scaled_array = min_max_scaler.fit_transform(float_array.reshape(-1,1))
  total2.iloc[:,i] = pd.DataFrame(scaled_array)

# %%
float_array = total.iloc[:,1].values.astype(float)
scaled_array = min_max_scaler.fit_transform(float_array.reshape(-1,1))
total2.iloc[:,1]=scaled_array

# %%
float_array = total.iloc[:,2].values.astype(float)
scaled_array = min_max_scaler.fit_transform(float_array.reshape(-1,1))
total2.iloc[:,2]=scaled_array

# %%
float_array = total.iloc[:,6].values.astype(float)
scaled_array = min_max_scaler.fit_transform(float_array.reshape(-1,1))
total2.iloc[:,6]=scaled_array

# %%
total.head(30)
# Out:
#               timestamp  meter_reading  ...  sea_level_pressure  wind_speed
# 0   2016-01-01 00:00:00      2733.1470  ...              1015.3         3.6
# 1   2016-01-01 01:00:00      2727.7944  ...              1015.6         4.1
# 2   2016-01-01 02:00:00      2777.4856  ...              1016.0         3.1
# 3   2016-01-01 03:00:00      2874.1859  ...              1016.6         3.1
# 4   2016-01-01 04:00:00      2945.0675  ...              1017.0         3.1
# 5   2016-01-01 05:00:00      3006.1453  ...              1017.2         1.5
# 6   2016-01-01 06:00:00      3075.5056  ...              1017.4         0.0
# 7   2016-01-01 07:00:00      3166.7465  ...              1017.3         0.0
# 8   2016-01-01 08:00:00      3044.4075  ...              1017.0         1.5
# 9   2016-01-01 09:00:00      2915.2176  ...              1016.9         0.0
# 10  2016-01-01 10:00:00      2855.9741  ...              1017.4         0.0
# 11  2016-01-01 11:00:00      2751.2731  ...              1017.2         0.0
# 12  2016-01-01 12:00:00      2725.4884  ...              1017.4         0.0
# 13  2016-01-01 13:00:00      2722.5905  ...              1018.0         0.0
# 14  2016-01-01 14:00:00      2797.9934  ...              1018.9         0.0
# 15  2016-01-01 15:00:00      2853.3830  ...              1019.4         0.0
# 16  2016-01-01 16:00:00      2835.0786  ...              1020.0         1.5
# 17  2016-01-01 17:00:00      2744.2500  ...              1020.5         0.0
# 18  2016-01-01 18:00:00      2690.7496  ...              1020.5         0.0
# 19  2016-01-01 19:00:00      2715.7423  ...              1019.8         0.0
# 20  2016-01-01 20:00:00      2702.4015  ...              1018.5         0.0
# 21  2016-01-01 21:00:00      2576.5353  ...              1017.7         0.0
# 22  2016-01-01 22:00:00      2504.1702  ...              1017.4         0.0
# 8781  2016-12-31 21:00:00       0.230413  ...            0.411765    0.298701
# 8782  2016-12-31 22:00:00       0.213846  ...            0.404844    0.233766
# 8783  2016-12-31 23:00:00       0.209710  ...            0.404844    0.168831
#
# [8784 rows x 7 columns]

# %%
model_1 = auto_arima(total2['meter_reading'],exogenous = total2.iloc[:,2:], max_p= 2, max_q=50,out_of_sample_size = 720)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/statespace/sarimax.py:949: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/statespace/sarimax.py:961: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
total.head()
# Out:
#              timestamp  meter_reading  ...  sea_level_pressure  wind_speed
# 0  2016-01-01 00:00:00      2733.1470  ...              1015.3         3.6
# 1  2016-01-01 01:00:00      2727.7944  ...              1015.6         4.1
# 2  2016-01-01 02:00:00      2777.4856  ...              1016.0         3.1
# 3  2016-01-01 03:00:00      2874.1859  ...              1016.6         3.1
# 4  2016-01-01 04:00:00      2945.0675  ...              1017.0         3.1
#
# [5 rows x 7 columns]

# %%
model_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 8064
# Model:               SARIMAX(2, 1, 2)   Log Likelihood              -59258.456
# Date:                Fri, 15 Nov 2019   AIC                         118538.913
# Time:                        07:37:02   BIC                         118615.858
# Sample:                             0   HQIC                        118565.239
#                                - 8064
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      2.4199      0.379      6.381      0.000       1.677       3.163
# x1           -45.6527      4.656     -9.805      0.000     -54.778     -36.527
# x2           -49.9881      4.453    -11.226      0.000     -58.715     -41.261
# x3             8.2310      0.439     18.735      0.000       7.370       9.092
# x4           225.6792      9.320     24.215      0.000     207.413     243.946
# x5            14.8525      2.776      5.350      0.000       9.412      20.293
# ar.L1          1.9289      0.001   3676.473      0.000       1.928       1.930
# ar.L2         -0.9969      0.000  -2041.748      0.000      -0.998      -0.996
# ma.L1         -1.9178      0.002  -1240.059      0.000      -1.921      -1.915
# ma.L2          0.9860      0.001    667.366      0.000       0.983       0.989
# sigma2      1.745e+05   1118.327    156.076      0.000    1.72e+05    1.77e+05
# ===================================================================================
# Ljung-Box (Q):                     2741.24   Jarque-Bera (JB):            163152.44
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.16   Skew:                            -0.04
# Prob(H) (two-sided):                  0.00   Kurtosis:                        25.04
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.58e+14. Standard errors may be unstable.
# """

# %%
fig = plt.figure(figsize=(50,10))
plt.title('site_id: 2 | Office' ,fontsize=15)
plt.xlabel("Date of measurement",fontsize=15)
plt.ylabel("meter_reading",fontsize=15)
plt.plot(total['meter_reading'][-720:].reset_index(drop = True))
plt.plot(model_1.predict(n_periods = 720, exogenous=total.iloc[-720:,2:]))
plt.savefig('1',bbox_inches="tight")

# %%
model_4 = auto_arima(total3['meter_reading'],exogenous = total3.iloc[:,2:], max_p= 5, max_q=4,max_P = 8, S=24,out_of_sample_size = 720)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/statespace/sarimax.py:949: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/statespace/sarimax.py:961: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/statespace/sarimax.py:949: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/statespace/sarimax.py:961: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/statespace/sarimax.py:949: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/statespace/sarimax.py:961: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/statespace/sarimax.py:949: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/statespace/sarimax.py:961: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/statespace/sarimax.py:949: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/statespace/sarimax.py:961: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/statespace/sarimax.py:949: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/statespace/sarimax.py:961: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.6/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
auto_arima()

# %%
total3.head()
# Out:
#              timestamp  meter_reading  ...  sea_level_pressure  wind_speed
# 0  2016-01-01 00:00:00       0.221033  ...            0.553633    0.233766
# 1  2016-01-01 01:00:00       0.220558  ...            0.564014    0.266234
# 2  2016-01-01 02:00:00       0.224972  ...            0.577855    0.201299
# 3  2016-01-01 03:00:00       0.233563  ...            0.598616    0.201299
# 4  2016-01-01 04:00:00       0.239860  ...            0.612457    0.201299
#
# [5 rows x 7 columns]

# %%
total.iloc[-720:,[0,2,3,4,5,6]]
# Out:
#                 timestamp  air_temperature  ...  sea_level_pressure  wind_speed
# 8064  2016-12-02 00:00:00             15.6  ...              1011.0         2.6
# 8065  2016-12-02 01:00:00             13.3  ...              1011.3         2.6
# 8066  2016-12-02 02:00:00             12.2  ...              1011.7         2.1
# 8067  2016-12-02 03:00:00             11.1  ...              1011.9         1.5
# 8068  2016-12-02 04:00:00             11.7  ...              1012.0         2.1
# ...                   ...              ...  ...                 ...         ...
# 8779  2016-12-31 19:00:00             15.0  ...              1012.4         3.6
# 8780  2016-12-31 20:00:00             16.1  ...              1011.7         3.6
# 8781  2016-12-31 21:00:00             16.7  ...              1011.2         4.6
# 8782  2016-12-31 22:00:00             16.7  ...              1011.0         3.6
# 8783  2016-12-31 23:00:00             16.7  ...              1011.0         2.6
#
# [720 rows x 6 columns]

# %%
fig = plt.figure(figsize=(30,10))
plt.title('site_id: 2 | Office' ,fontsize=15)
plt.xlabel("Date of measurement",fontsize=15)
plt.ylabel("meter_reading",fontsize=15)
plt.plot(total3['meter_reading'][-720:].reset_index(drop = True))
plt.plot(model_4.predict(n_periods = 720, exogenous=total3.iloc[-720:,2:]))

# %%
model_4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 8064
# Model:               SARIMAX(5, 1, 3)   Log Likelihood               15952.340
# Date:                Fri, 22 Nov 2019   AIC                         -31874.681
# Time:                        12:28:07   BIC                         -31769.755
# Sample:                             0   HQIC                        -31838.781
#                                - 8064
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   3.971e-06   5.17e-05      0.077      0.939   -9.73e-05       0.000
# x1             0.0350      0.018      1.932      0.053      -0.001       0.070
# x2             0.0509      0.013      4.051      0.000       0.026       0.076
# x3            -0.0362      0.006     -5.729      0.000      -0.049      -0.024
# x4             0.3171      0.027     11.766      0.000       0.264       0.370
# x5             0.0006      0.003      0.203      0.839      -0.005       0.006
# ar.L1          1.1128      0.026     43.370      0.000       1.063       1.163
# ar.L2         -0.4087      0.048     -8.558      0.000      -0.502      -0.315
# ar.L3          0.3208      0.048      6.711      0.000       0.227       0.414
# ar.L4          0.0501      0.017      3.012      0.003       0.018       0.083
# ar.L5         -0.2991      0.007    -42.446      0.000      -0.313      -0.285
# ma.L1         -0.7273      0.026    -28.141      0.000      -0.778      -0.677
# ma.L2          0.1825      0.040      4.559      0.000       0.104       0.261
# ma.L3         -0.3228      0.034     -9.521      0.000      -0.389      -0.256
# sigma2         0.0011   6.57e-06    169.696      0.000       0.001       0.001
# ===================================================================================
# Ljung-Box (Q):                     2531.51   Jarque-Bera (JB):            451709.46
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.36   Skew:                             0.69
# Prob(H) (two-sided):                  0.00   Kurtosis:                        39.64
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
total3.head()
# Out:
#              timestamp  meter_reading  ...  sea_level_pressure  wind_speed
# 0  2016-01-01 00:00:00       0.221033  ...            0.553633    0.233766
# 1  2016-01-01 01:00:00       0.220558  ...            0.564014    0.266234
# 2  2016-01-01 02:00:00       0.224972  ...            0.577855    0.201299
# 3  2016-01-01 03:00:00       0.233563  ...            0.598616    0.201299
# 4  2016-01-01 04:00:00       0.239860  ...            0.612457    0.201299
#
# [5 rows x 7 columns]

# %%
tmp = pd.DataFrame(date_tmp).rename(columns = {'timestamp' : 'weekday'})

# %%
date_tmp = total3['timestamp']

# %%
tmp['weekday'] = pd.to_datetime(tmp['weekday'])

# %%
tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 1 columns):
# weekday    8784 non-null int64
# dtypes: int64(1)
# memory usage: 68.8 KB

# %%
tmp = pd.DataFrame(tmp.set_index('weekday').index.weekday)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-134-c08253be7bba> in <module>()
# ----> 1 tmp = pd.DataFrame(tmp.set_index('weekday').index.weekday)
#
# AttributeError: 'Int64Index' object has no attribute 'weekday'
